# %% [markdown]
# <a href="https://colab.research.google.com/github/Bosy-Ayman/IR/blob/main/IR_Week(7)_Query_Expansion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **The learning outcomes of the this notebook are:**
#
# - Apply query expansion (QE) using the pseudo-relevance feedback (PRF) approach
# (with RM3 as the term selection model).
# - Evaluate and compare the results of retrieval models with and without QE.
# - Study the effect of parameter settings with QE.

# %%
#install the Pyterrier framework
# !pip install python-terrier
# install the nltk modules
# !pip install nltk
# Out:
# Collecting python-terrier
#   Downloading python-terrier-0.10.0.tar.gz (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.6/107.6 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.5.3)
# Collecting wget (from python-terrier)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from python-terrier) (4.66.2)
# Collecting pyjnius>=1.4.2 (from python-terrier)
#   Downloading pyjnius-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 25.2 MB/s eta 0:00:00
# Collecting matchpy (from python-terrier)
#   Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.2.2)
# Collecting deprecated (from python-terrier)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting chest (from python-terrier)
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.11.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from python-terrier) (2.31.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.3.2)
# Collecting nptyping==1.4.4 (from python-terrier)
#   Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.10/dist-packages (from python-terrier) (10.1.0)
# Collecting ir_datasets>=0.3.2 (from python-terrier)
#   Downloading ir_datasets-0.5.6-py3-none-any.whl (335 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.2/335.2 kB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (3.1.3)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.14.1)
# Collecting ir_measures>=0.3.1 (from python-terrier)
#   Downloading ir_measures-0.3.3.tar.gz (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dill (from python-terrier)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.2 MB/s eta 0:00:00
# Collecting pytrec_eval_terrier>=0.5.3 (from python-terrier)
#   Downloading pytrec_eval_terrier-0.5.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 kB 19.8 MB/s eta 0:00:00
# Collecting typish>=1.7.0 (from nptyping==1.4.4->python-terrier)
#   Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.12.3)
# Collecting inscriptis>=2.2.0 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading inscriptis-2.5.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.9.4)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (6.0.1)
# Collecting trec-car-tools>=2.5.4 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting lz4>=3.1.10 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.9 MB/s eta 0:00:00
# Collecting warc3-wet>=0.2.3 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Collecting warc3-wet-clueweb09>=0.2.5 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting zlib-state>=0.1.3 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading zlib-state-0.1.6.tar.gz (9.5 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ijson>=3.1.3 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading ijson-3.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 10.7 MB/s eta 0:00:00
# Collecting pyautocorpus>=0.1.1 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading pyautocorpus-0.1.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (379 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 379.9/379.9 kB 31.0 MB/s eta 0:00:00
# Collecting unlzw3>=0.2.1 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading unlzw3-0.2.2-py3-none-any.whl (6.1 kB)
# Collecting cwl-eval>=1.0.10 (from ir_measures>=0.3.1->python-terrier)
#   Downloading cwl-eval-1.0.12.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (2024.2.2)
# Collecting heapdict (from chest->python-terrier)
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->python-terrier) (2.1.5)
# Collecting multiset<3.0,>=2.0 (from matchpy->python-terrier)
#   Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->python-terrier) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->python-terrier) (3.3.0)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels->python-terrier) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels->python-terrier) (24.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->ir_datasets>=0.3.2->python-terrier) (2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.4->statsmodels->python-terrier) (1.16.0)
# Collecting cbor>=1.0.0 (from trec-car-tools>=2.5.4->ir_datasets>=0.3.2->python-terrier)
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: python-terrier, ir_measures, chest, wget, cwl-eval, warc3-wet-clueweb09, zlib-state, cbor
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.10.0-py3-none-any.whl size=115531 sha256=c053404a123673487e44657d6f4aa37a22e7a686d507d13715e0f2359efd88ae
#   Stored in directory: /root/.cache/pip/wheels/79/7c/8f/679a982895c53af35178eceda648a4bc9a9af6af5542e31a0e
#   Building wheel for ir_measures (setup.py) ... done
#   Created wheel for ir_measures: filename=ir_measures-0.3.3-py3-none-any.whl size=61183 sha256=654c4a3c779e91c6b4ab6e458ef34eed6d6814cc2c28e9dc6714d71b57c031f2
#   Stored in directory: /root/.cache/pip/wheels/9f/0e/22/718279f23fef1673a4c5e433881c25080a6afaa147e007183e
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7612 sha256=53bd65b31055a0d08ce190e7c47d8959cbf01be809e27663ec36262f67ebc400
#   Stored in directory: /root/.cache/pip/wheels/88/cf/99/4773b31f855f9ecedc32a0ae400f7a4a3001b37c439b6d1a73
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=11c42aed50d43cb9ab65d659e40d470d37f4aed8a7a78f447e835b2f647165f0
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.12-py3-none-any.whl size=38068 sha256=c0a5d8a6c5fdab315576af7151e4ceee7c014d0a2f908edb7007a80872fbedb9
#   Stored in directory: /root/.cache/pip/wheels/3d/c1/94/94a3e5379b1aa8fb7c7f1ad1956305d5edc98ef745b6067d87
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18919 sha256=77b009966acb9757a019495be939fcf10046e6f150ccf3ea75fecf775457abc0
#   Stored in directory: /root/.cache/pip/wheels/1a/d7/91/7ffb991df87e62355d945745035470ba2616aa3d83a250b5f9
#   Building wheel for zlib-state (pyproject.toml) ... done
#   Created wheel for zlib-state: filename=zlib_state-0.1.6-cp310-cp310-linux_x86_64.whl size=21163 sha256=42cf08549e2bbaae18491c1fbf14dcd50e6638f5e14d0b6df31a72f1639e2591
#   Stored in directory: /root/.cache/pip/wheels/32/72/7e/aff80f26e926b6e1fb08dfb52aba03c0e058f5e2258deb50a9
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp310-cp310-linux_x86_64.whl size=53434 sha256=7e0afecfa1f24d22e47ad4fade06409f4a6e6a5861d359cd66a151634fb2b5b1
#   Stored in directory: /root/.cache/pip/wheels/85/df/c9/b39e40eccaf76dbd218556639a6dc81562226f4c6a64902c85
# Successfully built python-terrier ir_measures chest wget cwl-eval warc3-wet-clueweb09 zlib-state cbor
# Installing collected packages: wget, warc3-wet-clueweb09, warc3-wet, typish, pyjnius, multiset, ijson, heapdict, cbor, zlib-state, unlzw3, trec-car-tools, pytrec_eval_terrier, pyautocorpus, nptyping, matchpy, lz4, dill, deprecated, cwl-eval, chest, ir_measures, inscriptis, ir_datasets, python-terrier
# Successfully installed cbor-1.0.0 chest-0.2.3 cwl-eval-1.0.12 deprecated-1.2.14 dill-0.3.8 heapdict-1.0.1 ijson-3.2.3 inscriptis-2.5.0 ir_datasets-0.5.6 ir_measures-0.3.3 lz4-4.3.3 matchpy-0.5.5 multiset-2.1.1 nptyping-1.4.4 pyautocorpus-0.1.12 pyjnius-1.6.1 python-terrier-0.10.0 pytrec_eval_terrier-0.5.6 trec-car-tools-2.6 typish-1.9.3 unlzw3-0.2.2 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wget-3.2 zlib-state-0.1.6
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %% [markdown]
# ## **The learning outcomes of the this notebook are:**
#
# - Apply query expansion (QE) using the pseudo-relevance feedback (PRF) approach
# (with RM3 as the term selection model).

# %%
import pandas as pd
import pyterrier as pt
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import re
import os
pd.set_option('display.max_colwidth', 150)

# %% [markdown]
# Since we need to apply QE, we need to install an additional PyTerrier package for pseudo-relevance feedback (**PRF**).

# %%
# Need to install additional terrier package for PRF. It will take around 1 min
# !git clone https://github.com/terrierteam/terrier-prf/
# !apt-get install maven   #used for Java projects to manage project dependencies and build processes
# %cd /content/terrier-prf/
# !mvn install
# !pwd
# %cd ..
# Out:
# fatal: destination path 'terrier-prf' already exists and is not an empty directory.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# maven is already the newest version (3.6.3-5).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# /content/terrier-prf
# [INFO] Scanning for projects...
# [INFO]
# [INFO] ----------------------< org.terrier:terrier-prf >-----------------------
# [INFO] Building terrier-prf 0.2-SNAPSHOT
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ terrier-prf ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/terrier-prf/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.1:compile (default-compile) @ terrier-prf ---
# [INFO] Nothing to compile - all classes are up to date
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ terrier-prf ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] skip non existing resourceDirectory /content/terrier-prf/src/test/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.1:testCompile (default-testCompile) @ terrier-prf ---
# [INFO] Nothing to compile - all classes are up to date
# [INFO]
# [INFO] --- maven-surefire-plugin:2.12.4:test (default-test) @ terrier-prf ---
# [INFO] Surefire report directory: /content/terrier-prf/target/surefire-reports
#
# -------------------------------------------------------
#  T E S T S
# -------------------------------------------------------
# Running org.terrier.querying.TestRM
# terrier.etc=/tmp/junit6178407516014306103
# Creating collection.spec file.
# Creating jforests.properties file.
# Creating features.list file.
# Creating logging configuration (logback.xml) file in /tmp/junit6178407516014306103/
# Creating terrier.properties file.
# 12:22:05.651 [main] DEBUG org.terrier.structures.Index - Files  /tmp/junit6178407516014306103/data.properties doesn't exist
# Setup complete for TestRM#testItWorksRM3
# 12:22:06.034 [main] DEBUG org.terrier.structures.Index - Files  /tmp/junit6178407516014306103/data-1.properties doesn't exist
# 12:22:06.049 [main] INFO  o.t.structures.indexing.Indexer - creating the data structures data-1_1
# 12:22:06.053 [main] DEBUG org.terrier.structures.Index - Files  /tmp/junit6178407516014306103/data-1_1.properties doesn't exist
# 12:22:06.068 [main] DEBUG org.terrier.structures.Index - Creating new index : /tmp/junit6178407516014306103/data-1_1.properties
# 12:22:06.138 [main] DEBUG o.t.utility.RuntimeMemoryChecker - memory.reserved=200 MiB memory.heap.usage=0.7
# 12:22:06.141 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-valuefactory
# 12:22:06.148 [main] INFO  o.t.s.indexing.LexiconBuilder - LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 12:22:06.196 [main] DEBUG o.t.utility.RuntimeMemoryChecker - memory.reserved=200 MiB memory.heap.usage=0.7
# 12:22:06.197 [main] DEBUG o.t.s.i.CompressingMetaIndexBuilder - Initialising CompressingMetaIndexBuilder
# 12:22:06.244 [main] INFO  o.t.structures.indexing.Indexer - Collection #0 took 0 seconds to index (2 documents)
# 12:22:06.274 [main] DEBUG o.t.s.indexing.LexiconBuilder - flushing lexicon to disk after the direct index completed
# 12:22:06.276 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-keyfactory
# 12:22:06.283 [main] DEBUG o.t.s.s.FixedSizeTextFactory - FixedSizeTextFactory: maxKeyWrittenSize=61 for term of size 20
# 12:22:06.334 [main] INFO  o.t.s.indexing.LexiconBuilder - 1 lexicons to merge
# 12:22:06.341 [main] INFO  o.t.s.indexing.LexiconBuilder - Optimising structure lexicon
# 12:22:06.485 [main] INFO  o.t.s.i.FSOMapFileLexiconUtilities - Optimising lexicon with 11 entries
# 12:22:06.879 [main] INFO  o.t.structures.indexing.Indexer - Started building the inverted index...
# 12:22:06.916 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - creating inverted index
# 12:22:06.917 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-inputstream
# 12:22:06.920 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - Memory: already allocated in use is 61.6 MiB
# 12:22:06.931 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - Memory: free is 2.9 GiB / 1 threads
# 12:22:06.931 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - Memory threshold is 2.3 GiB
# 12:22:06.933 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - projectedPointerCount 273310176
# 12:22:06.934 [main] INFO  o.t.s.i.c.InvertedIndexBuilder - BasicMemSizeLexiconScanner: lexicon scanning until approx 2.3 GiB of memory is consumed
# 12:22:06.940 [main] INFO  o.t.s.i.c.InvertedIndexBuilder - Iteration 1 of 1 (estimated) iterations
# 12:22:06.946 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - Scanning lexicon for 2.3 GiB memory -- upto 273310176 pointers
# 12:22:06.954 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - All of lexicon consumed using 12 pointers, under memory threshold
# 12:22:06.960 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - Selected 11 terms, 12 pointers for this iteration
# 12:22:06.962 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - time to process part of lexicon: 0.021
# 12:22:06.983 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - free: 142.4 MiB; total: 206 MiB; max: 3.2 GiB; 69.1% free; 6.3% allocated;
# 12:22:06.985 [main] DEBUG org.terrier.structures.Index - Attempting to load structure direct-inputstream
# 12:22:06.988 [main] DEBUG org.terrier.structures.Index - Attempting to load structure document-inputstream
# 12:22:06.994 [main] DEBUG org.terrier.structures.Index - Attempting to load structure document-factory
# 12:22:07.029 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - time to traverse direct file: 0.045
# 12:22:07.030 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - free: 140.6 MiB; total: 206 MiB; max: 3.2 GiB; 68.3% free; 6.3% allocated;
# 12:22:07.037 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - time to write inverted file: 0.005
# 12:22:07.039 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - temporary memory used: 96 B
# 12:22:07.040 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - free: 140.4 MiB; total: 206 MiB; max: 3.2 GiB; 68.2% free; 6.3% allocated;
# 12:22:07.040 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - time to perform one iteration: 0.1
# 12:22:07.041 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - number of pointers processed: 12
# 12:22:07.041 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-inputstream
# 12:22:07.156 [main] INFO  o.t.s.indexing.LexiconBuilder - Optimising structure lexicon
# 12:22:07.156 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-keyfactory
# 12:22:07.157 [main] DEBUG o.t.s.s.FixedSizeTextFactory - FixedSizeTextFactory: maxKeyWrittenSize=61 for term of size 20
# 12:22:07.157 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-valuefactory
# 12:22:07.157 [main] INFO  o.t.s.i.FSOMapFileLexiconUtilities - Optimising lexicon with 11 entries
# 12:22:07.169 [main] INFO  o.t.structures.indexing.Indexer - Finished building the inverted index...
# 12:22:07.173 [main] INFO  o.t.structures.indexing.Indexer - Time elapsed for inverted file: 0
# 12:22:07.199 [main] DEBUG org.terrier.structures.Index - Loading existing index : /tmp/junit6178407516014306103/data-1.properties
# 12:22:07.201 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-valuefactory
# 12:22:07.210 [main] DEBUG org.terrier.structures.Index - Attempting to load structure document
# 12:22:07.213 [main] DEBUG org.terrier.structures.Index - Attempting to load structure document-factory
# 12:22:07.217 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon
# 12:22:07.219 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-keyfactory
# 12:22:07.220 [main] DEBUG o.t.s.s.FixedSizeTextFactory - FixedSizeTextFactory: maxKeyWrittenSize=61 for term of size 20
# 12:22:07.233 [main] DEBUG org.terrier.structures.Index - Attempting to load structure meta
# 12:22:07.254 [main] INFO  o.t.structures.CompressingMetaIndex - Structure meta reading lookup file into memory
# 12:22:07.261 [main] DEBUG o.t.structures.CompressingMetaIndex - docid2offsets.length: 2 ZIP_COMPRESSION_LEVEL: 5 recordLength: 61
# 12:22:07.264 [main] INFO  o.t.structures.CompressingMetaIndex - Structure meta loading data file into memory
# 12:22:07.265 [main] DEBUG o.t.structures.CompressingMetaIndex - Caching metadata file /tmp/junit6178407516014306103/data-1.meta.zdata to memory
# 12:22:07.268 [main] DEBUG org.terrier.structures.Index - Attempting to load structure direct
# 12:22:07.274 [main] DEBUG org.terrier.structures.Index - Attempting to load structure inverted
# 12:22:07.301 [main] INFO  org.terrier.querying.LocalManager - Starting to execute query testQ - fox
# 12:22:07.302 [main] DEBUG org.terrier.querying.LocalManager - {decorate=on, parseql=on, applypipeline=on, parsecontrols=on, wmodel=DPH, localmatching=on, filters=on, rm=on, terrierql=on}
# 12:22:07.312 [main] DEBUG org.terrier.querying.LocalManager - terrierql(TerrierQLParser) => on
# 12:22:07.319 [main] INFO  org.terrier.querying.LocalManager - running process TerrierQLParser
# 12:22:07.334 [main] DEBUG org.terrier.querying.LocalManager - parsecontrols(TerrierQLToControls) => on
# 12:22:07.336 [main] INFO  org.terrier.querying.LocalManager - running process TerrierQLToControls
# 12:22:07.336 [main] DEBUG org.terrier.querying.LocalManager - parseql(TerrierQLToMatchingQueryTerms) => on
# 12:22:07.338 [main] INFO  org.terrier.querying.LocalManager - running process TerrierQLToMatchingQueryTerms
# 12:22:07.345 [main] DEBUG org.terrier.querying.LocalManager - matchopql(MatchingOpQLParser) => null
# 12:22:07.346 [main] DEBUG org.terrier.querying.LocalManager - applypipeline(ApplyTermPipeline) => on
# 12:22:07.348 [main] INFO  org.terrier.querying.LocalManager - running process ApplyTermPipeline(termpipelines=)
# 12:22:07.349 [main] DEBUG org.terrier.querying.LocalManager - localmatching(LocalManager$ApplyLocalMatching) => on
# 12:22:07.360 [main] INFO  org.terrier.querying.LocalManager - running process ApplyLocalMatching
# 12:22:07.364 [main] DEBUG org.terrier.querying.LocalManager - Using Matching as org.terrier.matching.daat.Full
# 12:22:07.367 [main] DEBUG org.terrier.querying.LocalManager - weighting model: DPH
# 12:22:07.373 [main] INFO  org.terrier.querying.LocalManager - fox { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.DPH@d554c5f] tags=[firstmatchscore]}
# 12:22:07.431 [main] DEBUG o.t.matching.matchops.SingleTermOp - Term fox field null stats term1 Nt=1 TF=1 maxTF=1 @{0 0 6} weight 1.0
# 12:22:07.453 [main] INFO  o.t.matching.PostingListManager - Query testQ with 1 terms has 1 posting lists
# 12:22:07.453 [main] DEBUG org.terrier.matching.Matching - plm initialised
# 12:22:07.453 [main] DEBUG org.terrier.matching.Matching - plm prepared
# 12:22:07.461 [main] DEBUG org.terrier.matching.Matching -  postingHeap.size()= 1 mts = [0]
# 12:22:07.470 [main] DEBUG org.terrier.matching.Matching - Requirement patterns: mustmatch=0 must not match=0
# 12:22:07.479 [main] DEBUG org.terrier.matching.Matching - Number of docs with +ve score: 1
# 12:22:07.483 [main] DEBUG org.terrier.matching.Matching - query testQ number of retrieved documents: 1
# 12:22:07.485 [main] DEBUG org.terrier.querying.LocalManager - rm(RM3) => on
# 12:22:07.511 [main] INFO  org.terrier.querying.LocalManager - running process RM3
# 12:22:07.531 [main] INFO  org.terrier.querying.RM1 - Found 5 terms after feedback document analysis
# 12:22:07.588 [main] INFO  org.terrier.querying.RM3 - Reformulated query testQ @ lambda=0.6: lazy^0.07999999821186066 jumped^0.07999999821186066 fox^0.6800000071525574 dog^0.07999999821186066 over^0.07999999821186066
# 12:22:07.589 [main] DEBUG org.terrier.querying.LocalManager - Using Matching as org.terrier.matching.daat.Full
# 12:22:07.590 [main] DEBUG org.terrier.querying.LocalManager - weighting model: DPH
# 12:22:07.595 [main] INFO  org.terrier.querying.LocalManager - lazy { req=null, w=0.07999999821186066, stats=null, models=[org.terrier.matching.models.DPH@1fd14d74] tags=[firstmatchscore]} jumped { req=null, w=0.07999999821186066, stats=null, models=[org.terrier.matching.models.DPH@563e4951] tags=[firstmatchscore]} fox { req=null, w=0.6800000071525574, stats=null, models=[org.terrier.matching.models.DPH@4066c471] tags=[firstmatchscore]} dog { req=null, w=0.07999999821186066, stats=null, models=[org.terrier.matching.models.DPH@2b175c00] tags=[firstmatchscore]} over { req=null, w=0.07999999821186066, stats=null, models=[org.terrier.matching.models.DPH@3eb81efb] tags=[firstmatchscore]}
# 12:22:07.596 [main] DEBUG o.t.matching.matchops.SingleTermOp - Term lazy field null stats term0 Nt=1 TF=1 maxTF=1 @{0 1 6} weight 0.1176470549564461
# 12:22:07.597 [main] DEBUG o.t.matching.matchops.SingleTermOp - Term jumped field null stats term4 Nt=1 TF=1 maxTF=1 @{0 1 4} weight 0.1176470549564461
# 12:22:07.597 [main] DEBUG o.t.matching.matchops.SingleTermOp - Term fox field null stats term1 Nt=1 TF=1 maxTF=1 @{0 0 6} weight 1.0
# 12:22:07.598 [main] DEBUG o.t.matching.matchops.SingleTermOp - Term dog field null stats term3 Nt=1 TF=1 maxTF=1 @{0 0 4} weight 0.1176470549564461
# 12:22:07.599 [main] DEBUG o.t.matching.matchops.SingleTermOp - Term over field null stats term5 Nt=1 TF=1 maxTF=1 @{0 3 0} weight 0.1176470549564461
# 12:22:07.599 [main] INFO  o.t.matching.PostingListManager - Query testQ with 5 terms has 5 posting lists
# 12:22:07.599 [main] DEBUG org.terrier.matching.Matching - plm initialised
# 12:22:07.599 [main] DEBUG org.terrier.matching.Matching - plm prepared
# 12:22:07.599 [main] DEBUG org.terrier.matching.Matching -  postingHeap.size()= 5 mts = [0, 1, 2, 3, 4]
# 12:22:07.599 [main] DEBUG org.terrier.matching.Matching - Requirement patterns: mustmatch=0 must not match=0
# 12:22:07.602 [main] DEBUG org.terrier.matching.Matching - Number of docs with +ve score: 1
# 12:22:07.603 [main] DEBUG org.terrier.matching.Matching - query testQ number of retrieved documents: 1
# 12:22:07.603 [main] DEBUG org.terrier.querying.LocalManager - qe(QueryExpansion) => null
# 12:22:07.603 [main] DEBUG org.terrier.querying.LocalManager - labels(org.terrier.learning.LabelDecorator) => null
# 12:22:07.603 [main] DEBUG org.terrier.querying.LocalManager - filters(LocalManager$PostFilterProcess) => on
# 12:22:07.604 [main] INFO  org.terrier.querying.LocalManager - running process PostFilterProcess
# 12:22:07.605 [main] DEBUG org.terrier.querying.LocalManager - decorate(SimpleDecorate) => on
# 12:22:07.608 [main] DEBUG org.terrier.querying.LocalManager - site(SiteFilter) => null
# 12:22:07.609 [main] DEBUG org.terrier.querying.LocalManager - scope(Scope) => null
# 12:22:07.620 [main] INFO  org.terrier.querying.LocalManager - Finished executing query testQ in 312ms - 1 results retrieved
# terrier.etc=/tmp/junit17848412504556349974
# Creating collection.spec file.
# Creating jforests.properties file.
# Creating features.list file.
# Creating logging configuration (logback.xml) file in /tmp/junit17848412504556349974/
# Creating terrier.properties file.
# 12:22:07.641 [main] DEBUG org.terrier.structures.Index - Files  /tmp/junit17848412504556349974/data.properties doesn't exist
# Setup complete for TestRM#testItWorksRM1
# 12:22:07.842 [main] DEBUG org.terrier.structures.Index - Files  /tmp/junit17848412504556349974/data-2.properties doesn't exist
# 12:22:07.843 [main] INFO  o.t.structures.indexing.Indexer - creating the data structures data-2_1
# 12:22:07.844 [main] DEBUG org.terrier.structures.Index - Files  /tmp/junit17848412504556349974/data-2_1.properties doesn't exist
# 12:22:07.844 [main] DEBUG org.terrier.structures.Index - Creating new index : /tmp/junit17848412504556349974/data-2_1.properties
# 12:22:07.844 [main] DEBUG o.t.utility.RuntimeMemoryChecker - memory.reserved=200 MiB memory.heap.usage=0.7
# 12:22:07.845 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-valuefactory
# 12:22:07.845 [main] INFO  o.t.s.indexing.LexiconBuilder - LexiconBuilder active - flushing every 100000 documents, or when memory threshold hit
# 12:22:07.847 [main] DEBUG o.t.utility.RuntimeMemoryChecker - memory.reserved=200 MiB memory.heap.usage=0.7
# 12:22:07.847 [main] DEBUG o.t.s.i.CompressingMetaIndexBuilder - Initialising CompressingMetaIndexBuilder
# 12:22:07.848 [main] INFO  o.t.structures.indexing.Indexer - Collection #0 took 0 seconds to index (2 documents)
# 12:22:07.851 [main] DEBUG o.t.s.indexing.LexiconBuilder - flushing lexicon to disk after the direct index completed
# 12:22:07.851 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-keyfactory
# 12:22:07.852 [main] DEBUG o.t.s.s.FixedSizeTextFactory - FixedSizeTextFactory: maxKeyWrittenSize=61 for term of size 20
# 12:22:07.853 [main] INFO  o.t.s.indexing.LexiconBuilder - 1 lexicons to merge
# 12:22:07.853 [main] INFO  o.t.s.indexing.LexiconBuilder - Optimising structure lexicon
# 12:22:07.854 [main] INFO  o.t.s.i.FSOMapFileLexiconUtilities - Optimising lexicon with 11 entries
# 12:22:08.133 [main] INFO  o.t.structures.indexing.Indexer - Started building the inverted index...
# 12:22:08.134 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - creating inverted index
# 12:22:08.134 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-inputstream
# 12:22:08.135 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - Memory: already allocated in use is 61.4 MiB
# 12:22:08.135 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - Memory: free is 2.9 GiB / 1 threads
# 12:22:08.135 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - Memory threshold is 2.3 GiB
# 12:22:08.135 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - projectedPointerCount 273327584
# 12:22:08.136 [main] INFO  o.t.s.i.c.InvertedIndexBuilder - BasicMemSizeLexiconScanner: lexicon scanning until approx 2.3 GiB of memory is consumed
# 12:22:08.138 [main] INFO  o.t.s.i.c.InvertedIndexBuilder - Iteration 1 of 1 (estimated) iterations
# 12:22:08.139 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - Scanning lexicon for 2.3 GiB memory -- upto 273327584 pointers
# 12:22:08.141 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - All of lexicon consumed using 12 pointers, under memory threshold
# 12:22:08.143 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - Selected 11 terms, 12 pointers for this iteration
# 12:22:08.144 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - time to process part of lexicon: 0.005
# 12:22:08.144 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - free: 152.6 MiB; total: 214 MiB; max: 3.2 GiB; 71.3% free; 6.6% allocated;
# 12:22:08.145 [main] DEBUG org.terrier.structures.Index - Attempting to load structure direct-inputstream
# 12:22:08.145 [main] DEBUG org.terrier.structures.Index - Attempting to load structure document-inputstream
# 12:22:08.146 [main] DEBUG org.terrier.structures.Index - Attempting to load structure document-factory
# 12:22:08.147 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - time to traverse direct file: 0.002
# 12:22:08.147 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - free: 152.4 MiB; total: 214 MiB; max: 3.2 GiB; 71.2% free; 6.6% allocated;
# 12:22:08.148 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - time to write inverted file: 0.001
# 12:22:08.148 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - temporary memory used: 96 B
# 12:22:08.148 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - free: 152.4 MiB; total: 214 MiB; max: 3.2 GiB; 71.2% free; 6.6% allocated;
# 12:22:08.149 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - time to perform one iteration: 0.01
# 12:22:08.149 [main] DEBUG o.t.s.i.c.InvertedIndexBuilder - number of pointers processed: 12
# 12:22:08.149 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-inputstream
# 12:22:08.282 [main] INFO  o.t.s.indexing.LexiconBuilder - Optimising structure lexicon
# 12:22:08.282 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-keyfactory
# 12:22:08.282 [main] DEBUG o.t.s.s.FixedSizeTextFactory - FixedSizeTextFactory: maxKeyWrittenSize=61 for term of size 20
# 12:22:08.283 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-valuefactory
# 12:22:08.283 [main] INFO  o.t.s.i.FSOMapFileLexiconUtilities - Optimising lexicon with 11 entries
# 12:22:08.288 [main] INFO  o.t.structures.indexing.Indexer - Finished building the inverted index...
# 12:22:08.288 [main] INFO  o.t.structures.indexing.Indexer - Time elapsed for inverted file: 0
# 12:22:08.291 [main] DEBUG org.terrier.structures.Index - Loading existing index : /tmp/junit17848412504556349974/data-2.properties
# 12:22:08.291 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-valuefactory
# 12:22:08.291 [main] DEBUG org.terrier.structures.Index - Attempting to load structure document
# 12:22:08.292 [main] DEBUG org.terrier.structures.Index - Attempting to load structure document-factory
# 12:22:08.292 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon
# 12:22:08.292 [main] DEBUG org.terrier.structures.Index - Attempting to load structure lexicon-keyfactory
# 12:22:08.293 [main] DEBUG o.t.s.s.FixedSizeTextFactory - FixedSizeTextFactory: maxKeyWrittenSize=61 for term of size 20
# 12:22:08.294 [main] DEBUG org.terrier.structures.Index - Attempting to load structure meta
# 12:22:08.297 [main] INFO  o.t.structures.CompressingMetaIndex - Structure meta reading lookup file into memory
# 12:22:08.298 [main] DEBUG o.t.structures.CompressingMetaIndex - docid2offsets.length: 2 ZIP_COMPRESSION_LEVEL: 5 recordLength: 61
# 12:22:08.298 [main] INFO  o.t.structures.CompressingMetaIndex - Structure meta loading data file into memory
# 12:22:08.298 [main] DEBUG o.t.structures.CompressingMetaIndex - Caching metadata file /tmp/junit17848412504556349974/data-2.meta.zdata to memory
# 12:22:08.298 [main] DEBUG org.terrier.structures.Index - Attempting to load structure direct
# 12:22:08.299 [main] DEBUG org.terrier.structures.Index - Attempting to load structure inverted
# 12:22:08.307 [main] INFO  org.terrier.querying.LocalManager - Starting to execute query testQ - fox
# 12:22:08.308 [main] DEBUG org.terrier.querying.LocalManager - {decorate=on, parseql=on, applypipeline=on, parsecontrols=on, wmodel=DPH, localmatching=on, filters=on, rm=on, terrierql=on}
# 12:22:08.312 [main] DEBUG org.terrier.querying.LocalManager - terrierql(TerrierQLParser) => on
# 12:22:08.313 [main] INFO  org.terrier.querying.LocalManager - running process TerrierQLParser
# 12:22:08.313 [main] DEBUG org.terrier.querying.LocalManager - parsecontrols(TerrierQLToControls) => on
# 12:22:08.314 [main] INFO  org.terrier.querying.LocalManager - running process TerrierQLToControls
# 12:22:08.315 [main] DEBUG org.terrier.querying.LocalManager - parseql(TerrierQLToMatchingQueryTerms) => on
# 12:22:08.316 [main] INFO  org.terrier.querying.LocalManager - running process TerrierQLToMatchingQueryTerms
# 12:22:08.316 [main] DEBUG org.terrier.querying.LocalManager - matchopql(MatchingOpQLParser) => null
# 12:22:08.316 [main] DEBUG org.terrier.querying.LocalManager - applypipeline(ApplyTermPipeline) => on
# 12:22:08.318 [main] INFO  org.terrier.querying.LocalManager - running process ApplyTermPipeline(termpipelines=)
# 12:22:08.318 [main] DEBUG org.terrier.querying.LocalManager - localmatching(LocalManager$ApplyLocalMatching) => on
# 12:22:08.318 [main] INFO  org.terrier.querying.LocalManager - running process ApplyLocalMatching
# 12:22:08.319 [main] DEBUG org.terrier.querying.LocalManager - Using Matching as org.terrier.matching.daat.Full
# 12:22:08.319 [main] DEBUG org.terrier.querying.LocalManager - weighting model: DPH
# 12:22:08.320 [main] INFO  org.terrier.querying.LocalManager - fox { req=null, w=1.0, stats=null, models=[org.terrier.matching.models.DPH@6057aebb] tags=[firstmatchscore]}
# 12:22:08.321 [main] DEBUG o.t.matching.matchops.SingleTermOp - Term fox field null stats term1 Nt=1 TF=1 maxTF=1 @{0 0 6} weight 1.0
# 12:22:08.321 [main] INFO  o.t.matching.PostingListManager - Query testQ with 1 terms has 1 posting lists
# 12:22:08.321 [main] DEBUG org.terrier.matching.Matching - plm initialised
# 12:22:08.321 [main] DEBUG org.terrier.matching.Matching - plm prepared
# 12:22:08.321 [main] DEBUG org.terrier.matching.Matching -  postingHeap.size()= 1 mts = [0]
# 12:22:08.321 [main] DEBUG org.terrier.matching.Matching - Requirement patterns: mustmatch=0 must not match=0
# 12:22:08.322 [main] DEBUG org.terrier.matching.Matching - Number of docs with +ve score: 1
# 12:22:08.322 [main] DEBUG org.terrier.matching.Matching - query testQ number of retrieved documents: 1
# 12:22:08.322 [main] DEBUG org.terrier.querying.LocalManager - rm(RM1) => on
# 12:22:08.323 [main] INFO  org.terrier.querying.LocalManager - running process RM1
# 12:22:08.323 [main] INFO  org.terrier.querying.RM1 - Found 5 terms after feedback document analysis
# 12:22:08.327 [main] INFO  org.terrier.querying.RM1 - Reformulated query: lazy^0.20000000298023224 jumped^0.20000000298023224 fox^0.20000000298023224 dog^0.20000000298023224 over^0.20000000298023224
# 12:22:08.327 [main] DEBUG org.terrier.querying.LocalManager - Using Matching as org.terrier.matching.daat.Full
# 12:22:08.327 [main] DEBUG org.terrier.querying.LocalManager - weighting model: DPH
# 12:22:08.328 [main] INFO  org.terrier.querying.LocalManager - lazy { req=null, w=0.20000000298023224, stats=null, models=[org.terrier.matching.models.DPH@63eef88a] tags=[firstmatchscore]} jumped { req=null, w=0.20000000298023224, stats=null, models=[org.terrier.matching.models.DPH@53251a66] tags=[firstmatchscore]} fox { req=null, w=0.20000000298023224, stats=null, models=[org.terrier.matching.models.DPH@6853425f] tags=[firstmatchscore]} dog { req=null, w=0.20000000298023224, stats=null, models=[org.terrier.matching.models.DPH@352c1b98] tags=[firstmatchscore]} over { req=null, w=0.20000000298023224, stats=null, models=[org.terrier.matching.models.DPH@21129f1f] tags=[firstmatchscore]}
# 12:22:08.336 [main] DEBUG o.t.matching.matchops.SingleTermOp - Term lazy field null stats term0 Nt=1 TF=1 maxTF=1 @{0 1 6} weight 1.0
# 12:22:08.336 [main] DEBUG o.t.matching.matchops.SingleTermOp - Term jumped field null stats term4 Nt=1 TF=1 maxTF=1 @{0 1 4} weight 1.0
# 12:22:08.340 [main] DEBUG o.t.matching.matchops.SingleTermOp - Term fox field null stats term1 Nt=1 TF=1 maxTF=1 @{0 0 6} weight 1.0
# 12:22:08.340 [main] DEBUG o.t.matching.matchops.SingleTermOp - Term dog field null stats term3 Nt=1 TF=1 maxTF=1 @{0 0 4} weight 1.0
# 12:22:08.342 [main] DEBUG o.t.matching.matchops.SingleTermOp - Term over field null stats term5 Nt=1 TF=1 maxTF=1 @{0 3 0} weight 1.0
# 12:22:08.342 [main] INFO  o.t.matching.PostingListManager - Query testQ with 5 terms has 5 posting lists
# 12:22:08.342 [main] DEBUG org.terrier.matching.Matching - plm initialised
# 12:22:08.342 [main] DEBUG org.terrier.matching.Matching - plm prepared
# 12:22:08.343 [main] DEBUG org.terrier.matching.Matching -  postingHeap.size()= 5 mts = [0, 1, 2, 3, 4]
# 12:22:08.343 [main] DEBUG org.terrier.matching.Matching - Requirement patterns: mustmatch=0 must not match=0
# 12:22:08.343 [main] DEBUG org.terrier.matching.Matching - Number of docs with +ve score: 1
# 12:22:08.343 [main] DEBUG org.terrier.matching.Matching - query testQ number of retrieved documents: 1
# 12:22:08.343 [main] DEBUG org.terrier.querying.LocalManager - qe(QueryExpansion) => null
# 12:22:08.343 [main] DEBUG org.terrier.querying.LocalManager - labels(org.terrier.learning.LabelDecorator) => null
# 12:22:08.343 [main] DEBUG org.terrier.querying.LocalManager - filters(LocalManager$PostFilterProcess) => on
# 12:22:08.344 [main] INFO  org.terrier.querying.LocalManager - running process PostFilterProcess
# 12:22:08.344 [main] DEBUG org.terrier.querying.LocalManager - decorate(SimpleDecorate) => on
# 12:22:08.344 [main] DEBUG org.terrier.querying.LocalManager - site(SiteFilter) => null
# 12:22:08.344 [main] DEBUG org.terrier.querying.LocalManager - scope(Scope) => null
# 12:22:08.344 [main] INFO  org.terrier.querying.LocalManager - Finished executing query testQ in 37ms - 1 results retrieved
# Tests run: 2, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 3.439 sec
#
# Results :
#
# Tests run: 2, Failures: 0, Errors: 0, Skipped: 0
#
# [INFO]
# [INFO] --- maven-jar-plugin:2.4:jar (default-jar) @ terrier-prf ---
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install (default-install) @ terrier-prf ---
# [INFO] Installing /content/terrier-prf/target/terrier-prf-0.2-SNAPSHOT.jar to /root/.m2/repository/org/terrier/terrier-prf/0.2-SNAPSHOT/terrier-prf-0.2-SNAPSHOT.jar
# [INFO] Installing /content/terrier-prf/pom.xml to /root/.m2/repository/org/terrier/terrier-prf/0.2-SNAPSHOT/terrier-prf-0.2-SNAPSHOT.pom
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  8.176 s
# [INFO] Finished at: 2024-03-24T12:22:08Z
# [INFO] ------------------------------------------------------------------------
# /content/terrier-prf
# /content

# %% [markdown]
# # **Preprocessing the data set**
# Tokenization, Removing stop words and Cleaning

# %%
nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
print(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Initialize Porter stemmer
stemmer = PorterStemmer()

# %%
def Stem_text(text):
    tokens = word_tokenize(text)
    stemmed_tokens = [stemmer.stem(word) for word in tokens]
    # print (tokens)
    return ' '.join(stemmed_tokens)

def clean(text):
   text = re.sub(r"[\.\,\#_\|\:\?\?\/\=\@]", " ", text) # remove special characters
   text = re.sub(r'\t', ' ', text) # remove tabs
   text = re.sub(r'\n', ' ', text) # remove line jump
   text = re.sub(r"\s+", " ", text) # remove extra white space
   text = text.strip()
   return text

def remove_stopwords(text):
    tokens = word_tokenize(text)
    filtered_tokens = [word.lower() for word in tokens if word.lower() not in stop_words] #Lower is used to normalize al the words make them in lower case
    # print('Tokens are:',tokens,'\n')
    return ' '.join(filtered_tokens)

#we need to process the query also as we did for documents
def preprocess(sentence):
  sentence = clean(sentence)
  sentence = remove_stopwords(sentence)
  sentence = Stem_text(sentence)
  return sentence

# %% [markdown]
# # Load Data for the Indexer

# %%
import zipfile
zip_file_name = 'cisi.zip'
with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
    zip_ref.extractall('cisi_dataset')
# !ls cisi_dataset
# Out:
# CISI.ALL  CISI.QRY  CISI.REL

# %%
def load_cisi_dataset(data_dir):
    documents_path = os.path.join(data_dir, 'CISI.ALL')
    queries_path = os.path.join(data_dir, 'CISI.QRY')
    qrels_path = os.path.join(data_dir, 'CISI.REL')

    documents_df = read_documents(documents_path)
    queries_df = read_queries(queries_path)
    qrels_df = read_qrels(qrels_path)
    return documents_df, queries_df, qrels_df

# Read documents from CISI.ALL file
def read_documents(documents_path):
    with open(documents_path, 'r') as file:
        lines = file.readlines()
    documents = []
    current_document = None
    for line in lines:
        if line.startswith('.I'):
            if current_document is not None:
                current_document['Text'] = current_document['Text'].split('\t')[0].strip()  # Remove anything after the first tab
                documents.append(current_document)
            current_document = {'ID': line.strip().split()[1], 'Text': ''}
        elif line.startswith('.T'):
            continue
        elif line.startswith('.A') or line.startswith('.B') or line.startswith('.W') or line.startswith('.X'):
            continue
        else:
            current_document['Text'] += line.strip() + ' '

    # Append the last document
    if current_document is not None:
        current_document['Text'] = current_document['Text'].split('\t')[0].strip()  # Remove anything after the first tab
        documents.append(current_document)
    documents_df = pd.DataFrame(documents)
    return documents_df

# Read queries from CISI.QRY file
def read_queries(queries_path):
    with open(queries_path, 'r') as file:
        lines = file.readlines()
    query_texts = []
    query_ids = []
    current_query_id = None
    current_query_text = []
    for line in lines:
        if line.startswith('.I'):
            if current_query_id is not None:
                query_texts.append(' '.join(current_query_text))
                current_query_text = []
            current_query_id = line.strip().split()[1]
            query_ids.append(current_query_id)
        elif line.startswith('.W'):
            continue
        elif line.startswith('.X'):
            break
        else:
            current_query_text.append(line.strip())
    # Append the last query
    query_texts.append(' '.join(current_query_text))
    queries_df = pd.DataFrame({
        'qid': query_ids,
        'raw_query': query_texts})
    return queries_df

# Read qrels from CISI.REL file
def read_qrels(qrels_path):
    qrels_df = pd.read_csv(qrels_path, sep='\s+', names=['qid','Q0','docno','label'])
    return qrels_df

# %%
data_dir = '/content/cisi_dataset'
documents_df, queries_df, qrels_df = load_cisi_dataset(data_dir)
documents_df['Text'][0]
# Out:
# "18 Editions of the Dewey Decimal Classifications Comaromi, J.P. The present study is a history of the DEWEY Decimal Classification.  The first edition of the DDC was published in 1876, the eighteenth edition in 1971, and future editions will continue to appear as needed.  In spite of the DDC's long and healthy life, however, its full story has never been told.  There have been biographies of Dewey that briefly describe his system, but this is the first attempt to provide a detailed history of the work that more than any other has spurred the growth of librarianship in this country and abroad. 1"

# %%
documents_df
# Out:
#         ID  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 1455  1456
# 1456  1457
# 1457  1458
# 1458  1459
# 1459  1460
#
#                                                                                                                                                        Text
# 0     18 Editions of the Dewey Decimal Classifications Comaromi, J.P. The present study is a history of the DEWEY Decimal Classification.  The first edi...
# 1     Use Made of Technical Libraries Slater, M. This report is an analysis of 6300 acts of use in 104 technical libraries in the United Kingdom. Librar...
# 2     Two Kinds of Power An Essay on Bibliographic Control Wilson, P. The relationships between the organization and control of writings and the organiz...
# 3     Systems Analysis of a University Library; final report and research project Buckland, M.K. The establishment of nine new universities in the 1960'...
# 4     A Library Management Game: a report on a research project Brophy, P. Although the use of games in professional education has become widespread onl...
# ...                                                                                                                                                     ...
# 1455  World Dynamics Forrester, J.W. Over the last several decades interest in economic development, population growth, and the world environment has ex...
# 1456  World Trends in Library Education Bramley, G. One of the most significant aspects of the evolution of librarianship in the twentieth century has b...
# 1457  Legal Restrictions on Exploitation of the Patent Monopoly: An Economic Analysis Baxter, W.A. The patent laws confer on a patentee power to exclude...
# 1458  Language and Thought Poluskin, V.A. This book considers the basic aspects of this complex problem - the historical and social essence of language ...
# 1459  Modern Integral Information Systems for Chemistry and Chemical Technology Chernyi, A.I. At the present time, about 15% of all the world publicatio...
#
# [1460 rows x 2 columns]

# %%
queries_df
# Out:
#      qid  \
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 107  108
# 108  109
# 109  110
# 110  111
# 111  112
#
#                                                                                                                                                  raw_query
# 0    What problems and concerns are there in making up descriptive titles? What difficulties are involved in automatically retrieving articles from app...
# 1    How can actually pertinent data, as opposed to references or entire articles themselves, be retrieved automatically in response to information req...
# 2                                                                                           What is information science?  Give definitions where possible.
# 3                                             Image recognition and any other methods of automatically transforming printed text into computer-ready form.
# 4    What special training will ordinary researchers and businessmen need for proper information management and unobstructed use of information retriev...
# ..                                                                                                                                                     ...
# 107  .T A Program for Machine-Mediated Searching .A Toliver, D. A technique of online instruction and assistance to bibliographic data base searchers c...
# 108  .T Author Cocitation:  A Literature Measure of Intellectual Structure .A White, H.D. Griffith, B.C. It is shown that the mapping of a particular a...
# 109  .T Progress in Documentation.  Word Processing: An Introduction and Appraisal .A Whitehead, J. The "Office of the Future," "Office Technology," "W...
# 110  .T Document Clustering Using an Inverted File Approach .A Willett, P. An automated document clustering procedure is described which does not requi...
# 111  .T A Fast Procedure for the Calculation of Similarity Coefficients in in Automatic Classification .A Willett, P. A fast algorithm is described for...
#
# [112 rows x 2 columns]

# %%
qrels_df
# Out:
#       qid   Q0  docno  label
# 0       1   28      0    0.0
# 1       1   35      0    0.0
# 2       1   38      0    0.0
# 3       1   42      0    0.0
# 4       1   43      0    0.0
# ...   ...  ...    ...    ...
# 3109  111  422      0    0.0
# 3110  111  448      0    0.0
# 3111  111  485      0    0.0
# 3112  111  503      0    0.0
# 3113  111  509      0    0.0
#
# [3114 rows x 4 columns]

# %%
#the docno will be our ID
documents_df["docno"]=documents_df["ID"].astype(str)
documents_df
# Out:
#         ID  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 1455  1456
# 1456  1457
# 1457  1458
# 1458  1459
# 1459  1460
#
#                                                                                                                                                        Text  \
# 0     18 Editions of the Dewey Decimal Classifications Comaromi, J.P. The present study is a history of the DEWEY Decimal Classification.  The first edi...
# 1     Use Made of Technical Libraries Slater, M. This report is an analysis of 6300 acts of use in 104 technical libraries in the United Kingdom. Librar...
# 2     Two Kinds of Power An Essay on Bibliographic Control Wilson, P. The relationships between the organization and control of writings and the organiz...
# 3     Systems Analysis of a University Library; final report and research project Buckland, M.K. The establishment of nine new universities in the 1960'...
# 4     A Library Management Game: a report on a research project Brophy, P. Although the use of games in professional education has become widespread onl...
# ...                                                                                                                                                     ...
# 1455  World Dynamics Forrester, J.W. Over the last several decades interest in economic development, population growth, and the world environment has ex...
# 1456  World Trends in Library Education Bramley, G. One of the most significant aspects of the evolution of librarianship in the twentieth century has b...
# 1457  Legal Restrictions on Exploitation of the Patent Monopoly: An Economic Analysis Baxter, W.A. The patent laws confer on a patentee power to exclude...
# 1458  Language and Thought Poluskin, V.A. This book considers the basic aspects of this complex problem - the historical and social essence of language ...
# 1459  Modern Integral Information Systems for Chemistry and Chemical Technology Chernyi, A.I. At the present time, about 15% of all the world publicatio...
#
#      docno
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 1455  1456
# 1456  1457
# 1457  1458
# 1458  1459
# 1459  1460
#
# [1460 rows x 3 columns]

# %%
queries_df["qid"]=queries_df["qid"].astype(str)
queries_df
# Out:
#      qid  \
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 107  108
# 108  109
# 109  110
# 110  111
# 111  112
#
#                                                                                                                                                  raw_query
# 0    What problems and concerns are there in making up descriptive titles? What difficulties are involved in automatically retrieving articles from app...
# 1    How can actually pertinent data, as opposed to references or entire articles themselves, be retrieved automatically in response to information req...
# 2                                                                                           What is information science?  Give definitions where possible.
# 3                                             Image recognition and any other methods of automatically transforming printed text into computer-ready form.
# 4    What special training will ordinary researchers and businessmen need for proper information management and unobstructed use of information retriev...
# ..                                                                                                                                                     ...
# 107  .T A Program for Machine-Mediated Searching .A Toliver, D. A technique of online instruction and assistance to bibliographic data base searchers c...
# 108  .T Author Cocitation:  A Literature Measure of Intellectual Structure .A White, H.D. Griffith, B.C. It is shown that the mapping of a particular a...
# 109  .T Progress in Documentation.  Word Processing: An Introduction and Appraisal .A Whitehead, J. The "Office of the Future," "Office Technology," "W...
# 110  .T Document Clustering Using an Inverted File Approach .A Willett, P. An automated document clustering procedure is described which does not requi...
# 111  .T A Fast Procedure for the Calculation of Similarity Coefficients in in Automatic Classification .A Willett, P. A fast algorithm is described for...
#
# [112 rows x 2 columns]

# %%
documents_df['processed_text'] = documents_df['Text'].apply(preprocess)
documents_df
# Out:
#         ID  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 1455  1456
# 1456  1457
# 1457  1458
# 1458  1459
# 1459  1460
#
#                                                                                                                                                        Text  \
# 0     18 Editions of the Dewey Decimal Classifications Comaromi, J.P. The present study is a history of the DEWEY Decimal Classification.  The first edi...
# 1     Use Made of Technical Libraries Slater, M. This report is an analysis of 6300 acts of use in 104 technical libraries in the United Kingdom. Librar...
# 2     Two Kinds of Power An Essay on Bibliographic Control Wilson, P. The relationships between the organization and control of writings and the organiz...
# 3     Systems Analysis of a University Library; final report and research project Buckland, M.K. The establishment of nine new universities in the 1960'...
# 4     A Library Management Game: a report on a research project Brophy, P. Although the use of games in professional education has become widespread onl...
# ...                                                                                                                                                     ...
# 1455  World Dynamics Forrester, J.W. Over the last several decades interest in economic development, population growth, and the world environment has ex...
# 1456  World Trends in Library Education Bramley, G. One of the most significant aspects of the evolution of librarianship in the twentieth century has b...
# 1457  Legal Restrictions on Exploitation of the Patent Monopoly: An Economic Analysis Baxter, W.A. The patent laws confer on a patentee power to exclude...
# 1458  Language and Thought Poluskin, V.A. This book considers the basic aspects of this complex problem - the historical and social essence of language ...
# 1459  Modern Integral Information Systems for Chemistry and Chemical Technology Chernyi, A.I. At the present time, about 15% of all the world publicatio...
#
#      docno  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 1455  1456
# 1456  1457
# 1457  1458
# 1458  1459
# 1459  1460
#
#                                                                                                                                              processed_text
# 0     18 edit dewey decim classif comaromi j p present studi histori dewey decim classif first edit ddc publish 1876 eighteenth edit 1971 futur edit con...
# 1     use made technic librari slater report analysi 6300 act use 104 technic librari unit kingdom librari use one aspect wider pattern inform use infor...
# 2     two kind power essay bibliograph control wilson p relationship organ control write organ control knowledg inform inevit enter stori write contain ...
# 3     system analysi univers librari ; final report research project buckland k establish nine new univers 1960 's provok highli stimul re-examin natur ...
# 4     librari manag game report research project brophi p although use game profession educ becom widespread last decad method use number field mani hun...
# ...                                                                                                                                                     ...
# 1455  world dynam forrest j w last sever decad interest econom develop popul growth world environ expand rapidli world-wid stress increas mani individu ...
# 1456  world trend librari educ bramley g one signific aspect evolut librarianship twentieth centuri emerg librari school potent factor shape new philoso...
# 1457  legal restrict exploit patent monopoli econom analysi baxter w patent law confer patente power exclud other make use sell invent further constitut...
# 1458  languag thought poluskin v book consid basic aspect complex problem - histor social essenc languag thought interact histor evolut essenc linguist ...
# 1459  modern integr inform system chemistri chemic technolog chernyi present time 15 % world public scientif technic literatur relat chemistri chemic te...
#
# [1460 rows x 4 columns]

# %%
queries_df["query"]=queries_df["raw_query"].apply(preprocess)
queries_df
# Out:
#      qid  \
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 107  108
# 108  109
# 109  110
# 110  111
# 111  112
#
#                                                                                                                                                  raw_query  \
# 0    What problems and concerns are there in making up descriptive titles? What difficulties are involved in automatically retrieving articles from app...
# 1    How can actually pertinent data, as opposed to references or entire articles themselves, be retrieved automatically in response to information req...
# 2                                                                                           What is information science?  Give definitions where possible.
# 3                                             Image recognition and any other methods of automatically transforming printed text into computer-ready form.
# 4    What special training will ordinary researchers and businessmen need for proper information management and unobstructed use of information retriev...
# ..                                                                                                                                                     ...
# 107  .T A Program for Machine-Mediated Searching .A Toliver, D. A technique of online instruction and assistance to bibliographic data base searchers c...
# 108  .T Author Cocitation:  A Literature Measure of Intellectual Structure .A White, H.D. Griffith, B.C. It is shown that the mapping of a particular a...
# 109  .T Progress in Documentation.  Word Processing: An Introduction and Appraisal .A Whitehead, J. The "Office of the Future," "Office Technology," "W...
# 110  .T Document Clustering Using an Inverted File Approach .A Willett, P. An automated document clustering procedure is described which does not requi...
# 111  .T A Fast Procedure for the Calculation of Similarity Coefficients in in Automatic Classification .A Willett, P. A fast algorithm is described for...
#
#                                                                                                                                                      query
# 0                                problem concern make descript titl difficulti involv automat retriev articl approxim titl usual relev content articl titl
# 1                                                                       actual pertin data oppos refer entir articl retriev automat respons inform request
# 2                                                                                                                       inform scienc give definit possibl
# 3                                                                                    imag recognit method automat transform print text computer-readi form
# 4                           special train ordinari research businessmen need proper inform manag unobstruct use inform retriev system problem like encount
# ..                                                                                                                                                     ...
# 107  program machine-medi search toliv techniqu onlin instruct assist bibliograph data base searcher call individu instruct data access ( iida ) develo...
# 108  author cocit literatur measur intellectu structur white h griffith b c shown map particular area scienc case inform scienc done use author unit an...
# 109  progress document word process introduct apprais whitehead j `` offic futur `` `` offic technolog `` `` word process `` `` electron mail `` `` ele...
# 110  document cluster use invert file approach willett p autom document cluster procedur describ requir use inter-docu similar matrix independ order do...
# 111  fast procedur calcul similar coeffici automat classif willett p fast algorithm describ compar list term repres document automat classif experi spe...
#
# [112 rows x 3 columns]

# %% [markdown]
# # Indexing:

# %%
if not pt.started():
  # In this lab, we need to specify that we start PyTerrier with PRF enabled
  pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])
# Out:
# terrier-assemblies 5.8 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.8 jar not found, downloading to /root/.pyterrier...
# Done
# terrier-prf -SNAPSHOT jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.10.0 has loaded Terrier 5.8 (built by craigm on 2023-11-01 18:05) and terrier-helper 0.0.8

# %%
indexer = pt.DFIndexer("./DatasetIndex", overwrite=True)
# index the text, record the docnos as metadata
index_ref = indexer.index(documents_df["processed_text"], documents_df["docno"])
print(index_ref.toString())
# Out:
# ./DatasetIndex/data.properties

# %%
index = pt.IndexFactory.of(index_ref)

# %% [markdown]
# ### **Experiments with PRF for QE**
#
# Once we have all our data ready, now we can see how to query expansion using PRF process.

# %% [markdown]
# **Experiment 1: query expansion using RM3**
#
# We will use BatchRetrieve PyTerrier class for retrieval using BM25 model. We will then apply query expansion using RM3 model and re-run the retrieval to see the effect of expansion.
#
# **What is RM3?**
#
# A relevance modelling (RM) approach to represent the topic described by the input query. RM3 benifits from a set of documents retrieved in response to that query, to generate a relevance model from which we can compute the probability of observing a term from these documents. Recall that the input query is one way to represent a topic, other representative terms can co-occur with these query terms.
#  ![rm1.PNG](data:image/png;base64,...)
# ![qe.PNG](data:image/png;base64,...)

# %% [markdown]
# Let's try a single query using BM25 as in earlier labs.

# %%
query="New Supreme Court rules."
query = preprocess(query)

results = bm25.search(query)
results
# Out:
#   qid  docid docno  rank      score                  query
# 0   1    990   991     0  10.281340  new suprem court rule
# 1   1    919   920     1   8.730488  new suprem court rule
# 2   1    837   838     2   8.685511  new suprem court rule
# 3   1    998   999     3   8.297720  new suprem court rule
# 4   1    264   265     4   8.119537  new suprem court rule
# 5   1    245   246     5   8.078718  new suprem court rule
# 6   1    903   904     6   7.921418  new suprem court rule
# 7   1    700   701     7   7.838100  new suprem court rule
# 8   1    713   714     8   7.824322  new suprem court rule
# 9   1    999  1000     9   7.788328  new suprem court rule

# %%
documents_df[['Text']][documents_df['docno'].isin(results['docno'].loc[0:4].tolist())]
# Out:
#                                                                                                                                                       Text
# 264  Code of Cataloging Rules Lubetzky, S. The following rules represent a system designed to produce an instrument essential to the operations and ser...
# 837  Prospects for a New General Classification Austin, Derec In traditional classification schemes, the universe of knowledge is broken down into self...
# 919  Main Entry for Serials Howard, J.H. The nature of serials is such that, in both the ALA Cataloging Rules for Author and Titles Entries and the Ang...
# 990  Filing Arrangement in the Library of Congress Catalogs Rather, John C. New filing rules have been developed for the catalogs of the Library of Con...
# 998  The Impact of International Standardization on the Rules of Entry for Serials Cannan, Judith Proctor The major provisions of the International Ser...

# %% [markdown]
# Let's now see the effect of query expansion on the query above. The process we will perform is as follows:
#
#
# 1. Retrieve an initial set of "psuedo-relevant documents" using a retrieval model (e.g., BM25).
# 2. Use **RM3** method to score terms in these documents
# 3. Expand the current query with top terms from Step 2
# 4. Retrieve the final set of documents with the expanded query.

# %%
# Define our retrieval model
bm25 = pt.BatchRetrieve(index, wmodel="BM25",num_results=10)

results = bm25.search(query)
results
# Out:
#   qid  docid docno  rank      score                  query
# 0   1    990   991     0  10.281340  new suprem court rule
# 1   1    919   920     1   8.730488  new suprem court rule
# 2   1    837   838     2   8.685511  new suprem court rule
# 3   1    998   999     3   8.297720  new suprem court rule
# 4   1    264   265     4   8.119537  new suprem court rule
# 5   1    245   246     5   8.078718  new suprem court rule
# 6   1    903   904     6   7.921418  new suprem court rule
# 7   1    700   701     7   7.838100  new suprem court rule
# 8   1    713   714     8   7.824322  new suprem court rule
# 9   1    999  1000     9   7.788328  new suprem court rule

# %%
# "rewrite" function from PyTerrier will be used to expand queries specifying RM3 as the model
# fb_docs ==> no. expansion documents
# fb_terms ==> no. expansion terms
rm3_expander = pt.rewrite.RM3(index,fb_terms=10, fb_docs=100)

#output of the BM25 will be fed into the RM3 expander for query expansion.
rm3_qe = bm25 >> rm3_expander
expanded_query = rm3_qe.search(query).iloc[0]["query"]

expanded_query
# Out:
# 'applypipeline:off principl^0.025388448 entri^0.043618690 court^0.150000006 catalog^0.066742927 titl^0.015446644 intern^0.030439461 new^0.150000006 rule^0.248586029 name^0.016188180 special^0.017572645 serial^0.067570113 object^0.018446825'

# %%
# Just print the expanded query with term scores
for s in expanded_query.split()[1:]:
  print(s)

print("\n" + query)
# Out:
# principl^0.025388448
# entri^0.043618690
# court^0.150000006
# catalog^0.066742927
# titl^0.015446644
# intern^0.030439461
# new^0.150000006
# rule^0.248586029
# name^0.016188180
# special^0.017572645
# serial^0.067570113
# object^0.018446825
#
# new suprem court rule

# %%
# After that you can search using the expanded query
expanded_query_formatted = ' '.join(expanded_query.split()[1:])

results_wqe = bm25.search(expanded_query_formatted)

print("   Before Expansion    After Expansion")
print(pd.concat([results[['docid','score']][0:5].add_suffix('_1'),
            results_wqe[['docid','score']][0:5].add_suffix('_2')], axis=1).fillna(''))

#Let's check the tweets text for the top 5 retrieved tweets
documents_df[['Text']][documents_df['docno'].isin(results_wqe['docno'].loc[0:5].tolist())]
# Out:
#    Before Expansion    After Expansion
#    docid_1    score_1  docid_2    score_2
# 0      990  10.281340      919  16.936712
# 1      919   8.730488      903  15.088821
# 2      837   8.685511      998  14.825252
# 3      998   8.297720      999  14.663473
# 4      264   8.119537     1002  12.508583
#                                                                                                                                                        Text
# 245   Cataloging Rules ad Principles Lubetzky, S. The present study was undertaken pursuant to an assignment by the Library of Congress.  The author was...
# 903   No Special Rules for Entry of Serials Carpenter, Michael One of the objectives of a library catalog is to enable one to determine what books or pu...
# 919   Main Entry for Serials Howard, J.H. The nature of serials is such that, in both the ALA Cataloging Rules for Author and Titles Entries and the Ang...
# 998   The Impact of International Standardization on the Rules of Entry for Serials Cannan, Judith Proctor The major provisions of the International Ser...
# 999   Serial Cataloging Problems: Rules of Entry and Definition of Title Simonton, Wesley Alternatives to the present rule for entry of serials in the A...
# 1002  AACR, ISBD(S) and ISSN: A Comment Fasana, Paul It has been proposed recently that rule 6 of the Anglo-American Cataloging Rules (AACR), relating t...

# %%
query2="Information Systems."
query2 = preprocess(query2)

results2 = bm25.search(query2)
results2
# Out:
#   qid  docid docno  rank     score          query
# 0   1    457   458     0  2.187661  inform system
# 1   1    537   538     1  2.184549  inform system
# 2   1   1037  1038     2  2.179465  inform system
# 3   1   1135  1136     3  2.150536  inform system
# 4   1    134   135     4  2.119528  inform system
# 5   1    614   615     5  2.113033  inform system
# 6   1    629   630     6  2.104819  inform system
# 7   1    610   611     7  2.095002  inform system
# 8   1    253   254     8  2.093127  inform system
# 9   1   1340  1341     9  2.091663  inform system

# %%
documents_df[['Text']][documents_df['docno'].isin(results2['docno'].loc[0:4].tolist())]
# Out:
#                                                                                                                                                        Text
# 134   Design of Information Systems and Services Borko, H. This review has selected for emphasis reports on concepts of systems analysis and on the proc...
# 457   Information Retrieval Systems Lancaster, F.W. This book is concerned primarily with those "intellectual" factors that significantly affect the per...
# 537   Information Retrieval Systems Lancaster, F.W. 1972 This book is concerned primarily with those "intellectual" factors that significantly affect th...
# 1037  Management Misinformation Systems Ackoff, R.L. Five assumptions commonly made by designers of management information systems are identified.  It i...
# 1135  Data Retrieval Systems:  Specifics and Problems Shtein, V. S. The essential differences between data retrieval system and document retrieval syste...

# %%
# "rewrite" function from PyTerrier will be used to expand queries specifying RM3 as the model
# fb_docs ==> no. expansion documents
# fb_terms ==> no. expansion terms

rm3_expander2 = pt.rewrite.RM3(index,fb_terms=10, fb_docs=100)

# Now we expand the query and see the resulting query
# For RM3, we need to first retrieve a set of "psuedo-relevant documents" then pass them to the expansion model
rm3_qe = bm25 >> rm3_expander2
expanded_query = rm3_qe.search(query2).iloc[0]["query"] #command will return the expanded query inside a dataframe with one row, access that row (iloc[0])

# Just print the expanded query with term scores
for s in expanded_query.split()[1:]:
  print(s)

# Let's compare to the original query
print("\n" + query2)
# Out:
# system^0.300000012
# inform^0.300000012
# lin^0.038997713
# control^0.040105052
# chemic^0.031436931
# dissemin^0.025998477
# perform^0.066326477
# storag^0.045960996
# model^0.033966992
# primarili^0.030403221
# social^0.025998477
# manag^0.060805645
#
# inform system

# %%
# After that you can search using the expanded query
expanded_query_formatted = ' '.join(expanded_query.split()[1:])
results_wqe = bm25.search(expanded_query_formatted)

print("   Before Expansion    After Expansion")
print(pd.concat([results2[['docid','score']][0:5].add_suffix('_1'),
            results_wqe[['docid','score']][0:5].add_suffix('_2')], axis=1).fillna(''))
   #print(results_wqe[['docid','score']][0:5])

#Let's check the tweets text for the top 5 retrieved tweets
documents_df[['Text']][documents_df['docno'].isin(results_wqe['docno'].loc[0:5].tolist())]
# Out:
#    Before Expansion    After Expansion
#    docid_1   score_1  docid_2   score_2
# 0      457  2.187661     1037  5.364533
# 1      537  2.184549      537  4.721913
# 2     1037  2.179465      458  4.605914
# 3     1135  2.150536     1061  4.594120
# 4      134  2.119528      253  4.542392
#                                                                                                                                                        Text
# 253   Chemical Information Systems Hyde, E. Ash, J.E. The purpose of a chemical information system must not be restricted to the storage and retrieval o...
# 457   Information Retrieval Systems Lancaster, F.W. This book is concerned primarily with those "intellectual" factors that significantly affect the per...
# 458   Information Retrieval On-Line Lancaster, F.W. This book deals with on-line systems for bibliographic search and retrieval.  The literature on this...
# 537   Information Retrieval Systems Lancaster, F.W. 1972 This book is concerned primarily with those "intellectual" factors that significantly affect th...
# 1037  Management Misinformation Systems Ackoff, R.L. Five assumptions commonly made by designers of management information systems are identified.  It i...
# 1061  Patterns of Evaluation in Science: Institutionalization, Structure and Functions of the Referee System Zuckerman, H. Merton, R.K. The referee syst...
